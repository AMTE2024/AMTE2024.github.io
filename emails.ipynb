# %%
from PIL import Image, ImageDraw, ImageFont

# %%
fnt = ImageFont.truetype('Menlo.ttc', 196)

# %%
text = 'amte2022@parsaamini.net'
a = Image.new('L', fnt.getsize(text), 'white')
ImageDraw.Draw(a).text((0, top_pad), text, fill='black', font=fnt)
display(a.size)
display(a)
sz = tuple(map(lambda x: int(x / 15.5), a.size))
b = a.resize(sz, Image.Resampling.LANCZOS)
display(b.size)
display(b)
b.save('assets/workshop_contact.png')
# Out:
# (2714, 223)
# <PIL.Image.Image image mode=L size=2714x223>
# (175, 14)
# <PIL.Image.Image image mode=L size=175x14>

# %%
c = Image.open("workshop_contact.png")

# %%
display(c.size)
display(c)
# Out:
# (169, 20)
# <PIL.PngImagePlugin.PngImageFile image mode=LA size=169x20>
